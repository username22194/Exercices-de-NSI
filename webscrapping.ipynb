# %% [markdown]
# # TP Guidé : WebScrapping
# ## I) Le WebScrapping dans la vraie vie
#
# Le WebScrapping est une activité très utilisé dans l’industrie informatique. En effet
# c’est un outil très efficace pour récolter des données sur Internet et pouvoir les traiter.
# Cependant est ce que c’est légal ?
#
#
# Extrait de <i>L’usine Digitale</i>
#
# La pratique du web scraping pourrait être considérée comme un "vol de données"
# (atteinte au STAD) en s’appuyant sur l’article 323-3 du Code pénal qui énonce :
# "Le fait d’introduire frauduleusement des données dans un système de traitement
# automatisé, d’extraire, de détenir, de reproduire, de transmettre, de supprimer ou de
# modifier frauduleusement les données qu’il contient est puni de cinq ans d’emprisonnement et de 150 000 € d’amende. Lorsque cette infraction a été commise à l’encontre d’un système de traitement automatisé de données à caractère personnel mis
# en oeuvre par l’Etat, la peine est portée à sept ans d’emprisonnement et à 300 000
# € d’amende." Il conviendrait toutefois de caractériser l’intention frauduleuse du web
# scraping.
# On peut également considérer qu’il s’agit d’un acte de concurrence déloyale ou
# d’une pratique de parasitisme, la personne recourant au web scraping n’ayant pas effectué les mêmes efforts (en termes de communication, d’investissements techniques,
# etc.) que le teneur du site pour collecter ces données.
# En outre, ce point se double d’exigences impératives en matière de protection des
# données à caractère personnel des utilisateurs à l’heure où le RGPD constitue une
# donne incontournable dans la stratégie des entreprises connectées. Il met en exergue
# la nécessité d’une gouvernance des données à caractère personnel (tant organisationnelle que juridique ou technique)...

# %% [markdown]
# <i> Le mot du professeur </i>
#
# Pour ne pas tomber dans l'illégalité dans le webscrapping.
# * Ne publiez pas en ligne les informations que vous avez récupérer avec le webscrapping.
# * Limitez au maximum le nombre de connexion au site (1 connexion maximum par page), comme vous le feriez en naviguant à la main. Les connexions sont faites grâce au module requests. <b>NE METTEZ JAMAIS <code>requests</code> DANS UNE BOUCLE</b>
#
# Si les données sont en licence libre, alors vous avez le droit d’y accéder librement.

# %% [markdown]
# ## II) Installation des prerequis

# %% [markdown]
# Taper dans le terminal (en bas ou dans Terminal -> ouvrir Nouveau Terminal)
# ```
# pip install --user --trusted-host Pypi.org --proxy=10.0.0.1:3128 beautifulsoup4
# ```
#
# ```
# pip install --user --trusted-host Pypi.org --proxy=10.0.0.1:3128 requests
# ```

# %% [markdown]
# Cette commande permet d’installer la librairie beautifulsoup4 qui permet à partir
# du texte d’une page html d’obtenir un objet dans lequel on pourra naviguer.

# %% [markdown]
# ## III) Initialisation
#
# On va charger les librairies dont on aura besoin :

# %%
import requests
import time
from bs4 import BeautifulSoup
import os

# %% [markdown]
# Les connexions sortantes et entrantes du lycée passe par un "tunnel" appelé proxy. On va préparer une variable (de quel type) avec les coordonnées de ce tunnel.

# %%
proxies = {"http":"10.0.0.1:3128","https":"10.0.0.1:3128"}

# %% [markdown]
# On va aller chercher une liste d'animé sur le site suivant : https://www.senscritique.com/liste/liste_complete_anime/478051

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice</strong>
# Faire une variable <code>url</code> qui sera un string et qui aura pour valeur l'url précédente.
# </div>

# %%
url = ...
url = "https://www.senscritique.com/liste/liste_complete_anime/478051"

# %% [markdown]
# ## IV) Navigation sur le site et recherche des points clés

# %% [markdown]
# 1. Connectez vous avec votre navigateur à https://www.senscritique.com/liste/liste_complete_anime/478051

# %% [markdown]
# 2. Inspecter le titre du premier anime que vous voyez. Quelle est sa balise et si il a une classe quelle est sa classe (et ses autres attributs)

# %% [markdown]
# Réponse : <a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/elfen_lied/189186">Elfen Lied (2004)</a>

# %% [markdown]
# 3. Chercher en remontant l'inspecteur de code la plus petite balise contenant tous les animes. Vérifier que sa balise est un div et que sa classe est ```"List__WrapperLists-sc-13autox-3 bgPFiI"```. Que signifie List__Wrapper ? Est ce que cela a du sens que sa classe est List__Wrapper ?

# %% [markdown]
# Réponse : Cela signifie "emballage de liste" . Cela fait du sens, car c'est la liste de l'ensemble d'animes.

# %% [markdown]
# 4. Supposer que vous pouvez tout extraire. Proposez une méthode pour pouvoir extraire tous les animes de cette page.

# %% [markdown]
# Réponse : Copier l'ensemble du code de la balise.

# %% [markdown]
# ## V) Automatisation de la collecte d'information

# %% [markdown]
# 1. On se connecte au site via python en utilisant le package ```requests```. On utilise la fonction ```get``` du package ```requests``` avec les arguments ```url``` pour faire une requête GET à l'url et ```proxies``` pour préciser le tunnel de connexion (c'est un argument facultatif mais au lycée il faut absolument le mettre).
#
# Si on voulait faire un POST quelle fonction aurait-on utilisé et quels auraient été les arguments ?

# %% [markdown]
# Réponse :

# %%
response = requests.get(url,proxies = proxies)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:776, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     775 try:
# --> 776     self._prepare_proxy(conn)
#     777 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:1041, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1035 conn.set_tunnel(
#    1036     scheme=tunnel_scheme,
#    1037     host=self._tunnel_host,
#    1038     port=self.port,
#    1039     headers=self.proxy_headers,
#    1040 )
# -> 1041 conn.connect()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connection.py:611, in HTTPSConnection.connect(self)
#     610 sock: socket.socket | ssl.SSLSocket
# --> 611 self.sock = sock = self._new_conn()
#     612 server_hostname: str = self.host
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connection.py:218, in HTTPConnection._new_conn(self)
#     217 except OSError as e:
# --> 218     raise NewConnectionError(
#     219         self, f"Failed to establish a new connection: {e}"
#     220     ) from e
#     222 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000015D9A3A8700>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# ProxyError: ('Unable to connect to proxy', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000015D9A3A8700>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.senscritique.com', port=443): Max retries exceeded with url: /liste/liste_complete_anime/478051 (Caused by ProxyError('Unable to connect to proxy', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000015D9A3A8700>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# c:\Users\enzowu2\Documents\Chapitre 4  Parce que c'est notre Projet\webscrapping.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/enzowu2/Documents/Chapitre%204%20%20Parce%20que%20c%27est%20notre%20Projet/webscrapping.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> response = requests.get(url,proxies = proxies)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\adapters.py:513, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     510     raise RetryError(e, request=request)
#     512 if isinstance(e.reason, _ProxyError):
# --> 513     raise ProxyError(e, request=request)
#     515 if isinstance(e.reason, _SSLError):
#     516     # This branch is for urllib3 v1.22 and later.
#     517     raise SSLError(e, request=request)
#
# ProxyError: HTTPSConnectionPool(host='www.senscritique.com', port=443): Max retries exceeded with url: /liste/liste_complete_anime/478051 (Caused by ProxyError('Unable to connect to proxy', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000015D9A3A8700>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')))

# %% [markdown]
# 2. Afficher le contenu de la réponse ```response```. Le contenu est dans ```response.content```.

# %%
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\enzowu2\Documents\Chapitre 4  Parce que c'est notre Projet\webscrapping.ipynb Cell 26 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/enzowu2/Documents/Chapitre%204%20%20Parce%20que%20c%27est%20notre%20Projet/webscrapping.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> print(response.text)
#
# NameError: name 'response' is not defined

# %% [markdown]
# 3. Vous avez vu c'est moche et illisible. Pour le rendre lisible, on va le découper en suivant les balises html. Cette activité s'appeler "parser" le texte. L'outil en python qui permet de parser des pages html est ```BeautifulSoup``` du package ```bs4```. On va donc appeler la classe ```BeautifulSoup``` avec comme argument le contenu de la page ```response.content``` et ```"html.parser``` pour dire qu'on veut parser du html.
#
# Compléter la cellule pour afficher ```soup```

# %%
soup = BeautifulSoup(response.content,"html.parser")
print(soup.text)
# Out:
# Liste complète Anime - Liste de 235 séries - SensCritiqueExplorerConnexionInscriptionSensCritique>Slimky>Listes>Liste complète AnimeListe complète AnimeVoici la liste complète des animes que j'ai pu regarder (Géniaux ou Mauvais).Liste de 235 sériescréee il y a plus de 9 ans · modifiée il y a plus de 5 ans6.8Elfen Lied (2004)25 min. Date de première diffusion : 12 septembre 2007 (France). 1 saison.  Romance, Seinen, ComédieAnime (mangas) AT-XSlimky a mis 8/10.6.9Soul Eater (2008)Soru Ita25 min. Date de première diffusion : 7 octobre 2009 (France). 1 saison.  Action, Animation, Épouvante-horreurAnime (mangas) TV TokyoSlimky a mis 9/10.7.3Black Lagoon (2006)Burakku Ragūn25 min. Date de première diffusion : 9 avril 2006 (Japon). 1 saison.  Action, Seinen, ComédieAnime (mangas) Tokyo MXSlimky a mis 8/10.7.1Hellsing (2001)Herushingu25 min. Date de première diffusion : 11 octobre 2001 (Japon). 1 saison.  Animation, Action, Épouvante-horreurAnime (mangas) Fuji TVSlimky a mis 7/10.7.6Hellsing Ultimate (2006)Hellsing45 min. Date de première diffusion : 10 février 2006 (Japon). 1 saison.  Animation, Action, FantastiqueOAV Slimky a mis 9/10.5.9High School of the Dead (2010)Gakuen Mokushiroku: High School of the Dead25 min. Date de première diffusion : 27 juin 2010 (Japon). 1 saison.  Shōnen, Action, RomanceAnime (mangas) TV TokyoSlimky a mis 5/10.7.9Death Note (2006)25 min. Date de première diffusion : 2 février 2008 (France). 1 saison.  Thriller, Policier, ShōnenAnime (mangas) NTVSlimky a mis 8/10.6Sora no Otoshimono (2009)そらのおとしもの25 min. Date de première diffusion : 5 octobre 2009 (Japon). 2 saisons.  Action, Animation, ComédieAnime (mangas) TV AsahiSlimky a mis 7/10.6.9Angel Beats! (2010)25 min. Date de première diffusion : 10 juillet 2013 (France). 1 saison.  Seinen, Action, ComédieAnime (mangas) TBSSlimky a mis 8/10.5.7Date a Live (2013)25 min. Date de première diffusion : 31 mars 2013 (Japon).  Fantasy, Romance, ShōnenAnime (mangas) Tokyo MXSlimky a mis 4/10.6.8Love, Chunibyo & Other Delusions! (2012)Chuunibyou demo Koi ga Shitai!25 min. Date de première diffusion : 4 octobre 2012 (Japon). 1 saison.  Animation, Seinen, RomanceAnime (mangas) TBSSlimky a mis 7/10.Annotation :   7.4Spice and Wolf (2008)Ookami to Koushinryo24 min. Date de première diffusion : 8 janvier 2008 (Japon). 1 saison.  Action, Animation, FantastiqueAnime (mangas) Tokyo MXSlimky a mis 7/10.8.2Fullmetal Alchemist : Brotherhood (2009)Hagane no Renkinjutsushi : Brotherhood25 min. Date de première diffusion : 19 octobre 2009 (France). 1 saison.  Fantasy, Drame, ComédieAnime (mangas) TBSSlimky a mis 9/10.7.1Magi : The Labyrinth of Magic (2012)25 min. Date de première diffusion : 7 octobre 2012 (Japon). 1 saison.  Action, Animation, ComédieAnime (mangas) TBSSlimky a mis 7/10.8Ghost in the Shell : Stand Alone Complex (2002)Kōkaku Kidōtai: Stand Alone Complex25 min. Date de première diffusion : 1 octobre 2002 (France). 2 saisons.  Action, Science-fiction, PolicierAnime (mangas) AnimaxSlimky a mis 8/10.7.6Durarara!! (2010)25 min. Date de première diffusion : 8 janvier 2010 (Japon). 1 saison.  Seinen, Action, ComédieAnime (mangas) MBSSlimky a mis 7/10.7.9L'Attaque des Titans (2013)Shingeki no Kyojin25 min. Date de première diffusion : 5 septembre 2014 (France). 1 saison.  Animation, Aventure, FantasyAnime (mangas) MBSSlimky a mis 8/10.6.3Another (2012)20 min. Date de première diffusion : 10 janvier 2012 (Japon). 1 saison.  Action, Seinen, ThrillerAnime (mangas) Tokyo MXSlimky a mis 7/10.6.1The Future Diary (2011)Mirai Nikki25 min. Date de première diffusion : 9 octobre 2011 (Japon). 1 saison.  Action, Animation, DrameAnime (mangas) CTC (JA)Slimky a mis 8/10.4.6Akikan! (2008)25 min. Date de première diffusion : 22 décembre 2008 (Japon). 1 saison.  Action, Animation, DrameAnime (mangas) BS11Slimky a mis 1/10.7.5Anohana (2011)Ano Hi Mita Hana no Namae o Bokutachi wa Mada Shiranai20 min. Date de première diffusion : 15 avril 2011 (Japon). 1 saison.  Animation, Drame, RomanceAn ...

# %% [markdown]
# 4. Maintenant on va chercher nos animes. On a pas fait tout ça pour rien :) On va pas les chercher, on va les trouver tous avec la méthode ```find_all```. Ce dernier prend pour argument :
#    * un argument obligatoire : la balise de ce que l'on cherche.
#    * un argument facultatif : les attributs la balise que l'on cherche.
#
#   Recopier dans une variable ```classe``` du type ```string``` le contenu de l'attribut ```class``` de la balise du IV.3.

# %%
classe = ...
classe = "List__WrapperLists-sc-13autox-3 bgPFiI"

# %% [markdown]
# Comme l'attribut ```class``` est en fait une liste on va transformer le string en liste grace à la méthode ```split```. La méthode ```.split(" ")``` prendra le string et le séparera tous les espaces.

# %%
liste_classe = classe.split(" ")
liste_classe
# Out:
# ['List__WrapperLists-sc-13autox-3', 'bgPFiI']

# %% [markdown]
# Finalement notre recherche donne :

# %% [markdown]
# La liste des animes

# %%
liste_div = soup.find_all("div",{"class":classe.split(" ")})
liste_div
# Out:
# [<div class="List__WrapperLists-sc-13autox-3 bgPFiI"><div><div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/elfen_lied/189186" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.8</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/elfen_lied/189186">Elfen Lied (2004)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 12 septembre 2007 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Romance, Seinen, Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/ATX/527012"><span>AT-X</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 8/10.</p></div></div></div></div><div><div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-acti ...

# %% [markdown]
# 5. Regardons la longueur de ```liste_div```. On aimerait avoir une longueur de 1 pour être sûr de prendre le bon élément. Chercher la longueur de ```liste```.

# %%
len(liste_div)
# Out:
# 1

# %% [markdown]
# * Quelle est la longueur de ```liste_div``` ?
# * Est ce que c'est ce que vous voulez ?
# * Faite une variable ```tag_liste``` contenant l'unique élément de ```liste_div```.

# %% [markdown]
# Réponse : ...

# %%
tag_liste = liste_div[0]
tag_liste
# Out:
# <div class="List__WrapperLists-sc-13autox-3 bgPFiI"><div><div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/elfen_lied/189186" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.8</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/elfen_lied/189186">Elfen Lied (2004)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 12 septembre 2007 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Romance, Seinen, Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/ATX/527012"><span>AT-X</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 8/10.</p></div></div></div></div><div><div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actio ...

# %% [markdown]
# 6. Maintenant que l'on a la liste de tous les mangas on va chercher les informations de chaque manga. Chercher sur le navigateur le plus petit élément contenant toutes les informations sur un seul manga. Donner
#    * sa balise
#    * ses attributs.

# %% [markdown]
# Balise : <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"></div>
# Attribut : class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"

# %% [markdown]
# 7. Maintenant on refait l'étape 4 (```find_all```) avec la balise précédente. Ecrivez votre code en dessous.

# %%
manga = "ProductListItem__Container-sc-1jkxxpj-0 btjqXG"
liste_manga = manga.split(" ")
print(liste_manga)
liste_tag_manga_div = soup.find_all("div",{"class":manga.split(" ")})
liste_tag_manga_div
# Out:
# ['ProductListItem__Container-sc-1jkxxpj-0', 'btjqXG']
# [<div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/elfen_lied/189186" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.8</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/elfen_lied/189186">Elfen Lied (2004)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 12 septembre 2007 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Romance, Seinen, Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/ATX/527012"><span>AT-X</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 8/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/soul_eater/135129" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006496712/300/soul_eater.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Soul Eater" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Soul Eater" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006496712/300/soul_eater.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.9</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/soul_eater/135129">Soul Eater (2008)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Soru Ita</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 7 octobre 2009 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Action, Animation, Épouvante-horreur</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/TV_Tokyo/504130"><span>TV Tokyo</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 9/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/black_lagoon/125690" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000005764201/300/black_lagoon.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Black Lagoon" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Black Lagoon" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000005764201/300/black_lagoon.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">7.3</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/black_lagoon/125690">Black Lagoon (2006)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Burakku Ragūn</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 9 avril 2006 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Action, Seinen, Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Tokyo_MX/520250"><span>Tokyo MX</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 8/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/hellsing/120149" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000017942855/300/hellsing.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Hellsing" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Hellsing" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000017942855/300/hellsing.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">7.1</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/hellsing/120149">Hellsing (2001)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Herushingu</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 11 octobre 2001 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Animation, Action, Épouvante-horreur</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Fuji_TV/243010"><span>Fuji TV</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 7/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/hellsing_ultimate/465328" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000021380538/300/hellsing_ultimate.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Hellsing Ultimate" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Hellsing Ultimate" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000021380538/300/hellsing_ultimate.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">7.6</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/hellsing_ultimate/465328">Hellsing Ultimate (2006)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Hellsing</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">45 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 10 février 2006 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Animation, Action, Fantastique</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">OAV </span></span></span></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 9/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/high_school_of_the_dead/365018" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006495904/300/high_school_of_the_dead.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="High School of the Dead" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="High School of the Dead" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006495904/300/high_school_of_the_dead.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">5.9</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/high_school_of_the_dead/365018">High School of the Dead (2010)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Gakuen Mokushiroku: High School of the Dead</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 27 juin 2010 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Shōnen, Action, Romance</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/TV_Tokyo/504130"><span>TV Tokyo</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 5/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/death_note/360382" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000017947429/300/death_note.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Death Note" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Death Note" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000017947429/300/death_note.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">7.9</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/death_note/360382">Death Note (2006)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 2 février 2008 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Thriller, Policier, Shōnen</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/NTV/2252155"><span>NTV</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 8/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/sora_no_otoshimono/486894" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006519631/300/sora_no_otoshimono.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Sora no Otoshimono" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Sora no Otoshimono" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006519631/300/sora_no_otoshimono.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/sora_no_otoshimono/486894">Sora no Otoshimono (2009)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">そらのおとしもの</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 5 octobre 2009 (Japon). </span><span data-testid="nb_season">2 saisons.<!-- --> </span> <span data-testid="genres">Action, Animation, Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/TV_Asahi/1315179"><span>TV Asahi</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 7/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/angel_beats/428708" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006503547/300/angel_beats.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Angel Beats!" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Angel Beats!" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006503547/300/angel_beats.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.9</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/angel_beats/428708">Angel Beats! (2010)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 10 juillet 2013 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Seinen, Action, Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/TBS/1470607"><span>TBS</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 8/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/date_a_live/8459042" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006548054/300/date_a_live.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Date a Live" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Date a Live" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006548054/300/date_a_live.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">5.7</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/date_a_live/8459042">Date a Live (2013)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 31 mars 2013 (Japon). </span> <span data-testid="genres">Fantasy, Romance, Shōnen</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Tokyo_MX/520250"><span>Tokyo MX</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 4/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/love_chunibyo_other_delusions/8169829" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000019226113/300/love_chunibyo_other_delusions.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Love, Chunibyo &amp; Other Delusions!" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Love, Chunibyo &amp; Other Delusions!" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000019226113/300/love_chunibyo_other_delusions.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.8</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/love_chunibyo_other_delusions/8169829">Love, Chunibyo &amp; Other Delusions! (2012)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Chuunibyou demo Koi ga Shitai!</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 4 octobre 2012 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Animation, Seinen, Romance</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/TBS/1470607"><span>TBS</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 7/10.</p><div class="Annotation__Container-sc-tusli0-0 eZaOlf" data-testid="annotation"><p class="Text__SCText-s ...
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/spice_and_wolf/444961" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006507461/300/spice_and_wolf.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Spice and Wolf" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Spice and Wolf" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006507461/300/spice_and_wolf.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">7.4</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/spice_and_wolf/444961">Spice and Wolf (2008)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Ookami to Koushinryo</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">24 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 8 janvier 2008 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Action, Animation, Fantastique</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Tokyo_MX/520250"><span>Tokyo MX</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 7/10.</p></div></div></div>,
# ...
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/bakemonogatari/16732869" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000016835992/300/bakemonogatari.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Bakemonogatari" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Bakemonogatari" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000016835992/300/bakemonogatari.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">7.6</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/bakemonogatari/16732869">Bakemonogatari (2009)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 3 juillet 2009 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Animation, Romance, Seinen</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Tokyo_MX/520250"><span>Tokyo MX</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 7/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/btooom/8170808" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006511665/300/btooom.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Btooom!" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Btooom!" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006511665/300/btooom.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.3</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/btooom/8170808">Btooom! (2012)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 29 septembre 2012 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Romance, Science-fiction, Action</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Tokyo_MX/520250"><span>Tokyo MX</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 5/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/blood_lad/8192954" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000019263465/300/blood_lad.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Blood Lad" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Blood Lad" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000019263465/300/blood_lad.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.3</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/blood_lad/8192954">Blood Lad (2013)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 8 juillet 2013 (Japon). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Action, Comédie, Seinen</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Tokyo_MX/520250"><span>Tokyo MX</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 5/10.</p></div></div></div>,
#  <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/blood/434136" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006503569/300/blood.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Blood+" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Blood+" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006503569/300/blood.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">7</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/blood/434136">Blood+ (2005)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 23 septembre 2006 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Action, Animation, Drame</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/TBS/1470607"><span>TBS</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 6/10.</p></div></div></div>]

# %% [markdown]
# 8. Quelle est la longueur de votre ```find_all``` ? Est ce normal (comptez combien il y a de manga sur une page et comparez le à la longueur du ```find_all```).

# %% [markdown]
# Réponse : 31. C'est le nombre de mangas sur la page.

# %% [markdown]
# 9. Maintenant il va falloir rentrer dans le détail. On va procéder en 3 étapes
#    *  Exploration. On va prendre un tag en particulier et on va chercher où sont les informations précisément.
#    *  Automatisation. On va faire une fonction qui prend en entrée un ```tag``` et qui renvoie les informations qui nous interesse.
#    *  Récupération des informations. On va faire une boucle sur ```liste_tag_manga``` qui applique la fonction à chaque ```tag``` de la liste.

# %% [markdown]
#  9. 1. Faites une variable ```tag``` avec le premier élément de ```liste_tag_manga```

# %%
tag = liste_tag_manga[0]
tag
# Out:
# <div class="ProductListItem__Container-sc-1jkxxpj-0 btjqXG" data-testid="product-list-item"><div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/serie/elfen_lied/189186" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Elfen Lied" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006486809/300/elfen_lied.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">6.8</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 jnAqkx"><h3 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/serie/elfen_lied/189186">Elfen Lied (2004)</a></h3><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">25 min<!-- -->. </span><span data-testid="date-release">Date de première diffusion : 12 septembre 2007 (France). </span><span data-testid="nb_season">1 saison.<!-- --> </span> <span data-testid="genres">Romance, Seinen, Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Anime (mangas) </span></span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/ATX/527012"><span>AT-X</span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__AuthorInfo-sc-1jkxxpj-7 eWSucP duqTYx" data-testid="author-info"><a href="/Slimky">Slimky</a> a mis 8/10.</p></div></div></div>

# %% [markdown]
# 9. 2. Dans quelle balise et avec quel attribut est le titre du manga (Attention ne regardait pas que la classe)

# %% [markdown]
# Réponse : ........

# %% [markdown]
# 9. 3. Utiliser la fonction ```find_all``` pour trouver la balise avec le titre. Extraire l'unique élément de ce ```find_all```. Affecter le à une variable ```tag_titre```. Le titre est dans l'attribut ```texte```

# %%
...
tag_titre = tag.find_all("a",{"data-testid":"product-title"})[0]

# %%
titre = tag_titre.text
titre

# %% [markdown]
# 9. 4. De la même façon, trouvez la durée des épisodes, la date de première diffusion, le nombre de saisons et le genre.

# %% [markdown]
# 9. 5. Faites 5 fonctions qui prennent en argument un ```tag``` et qui renvoie respectivement
#     * le titre
#     * la durée des épisodes
#     * la date de première diffusion
#     * le nombre de saisons
#     * le genre

# %% [markdown]
# 9. 6. Appliquez ces fonctions à tous les ```tag``` de ```liste_tag_manga```. Mettez chaque résultat dans une liste différente : ```liste_titre```, ```liste_duree```, ```liste_release```, ```liste_number_season```, ```liste_genre```.

# %% [markdown]
# 9. 7. La commande suivante permet de faire une table avec tous les animes de façon rangée. Pour la faire on utilise la package pandas, qui gère les tables, appelés ```DataFrame```. La donnée de base est un dictionnaire où les clés sont les noms des colonnes que l'on veut pour notre tableau et les valeurs sont les listes de ce que l'on veut avoir. Mieux vaut comprendre sur un exemple. Le voici.

# %%
import pandas as pd
dataframe_manga = pd.DataFrame({
    "Titre":liste_titre,
    "Durée":liste_duree,
    "Diffusion":liste_release,
    "Nombre de Saisons":liste_number_season,
    "Genre":liste_genre
    })
dataframe_manga

# %% [markdown]
# 10. Faire une fonction qui à une ```liste_titre```, ```liste_duree```, ```liste_release```, ```liste_number_season```, ```liste_genre``` associe une liste de dictionnaire de la forme

# %%
{"Titre":titre_du_manga, "Durée":duree_du_manga,"Date de diffusion":release_manga,"Nombre de saisons":season_number,"Genre":genre}

# %% [markdown]
# ## Devoir Maison

# %% [markdown]
# Sur le site, il y a 8 pages d'anime. Nous avons analisé une page d'anime. Faite un ```Dataframe``` comme dans le 9.7. mais avec tous les animes du site.
