# %% [markdown]
# # Exercice 1
#
# Déterminez les renvois des fonctions $f$ et $g$ définies ci-dessous pour les appels $f(2),f(0),g(1)$ et $g(3)$.

# %%
def f(x):
    y = x**2-3
    return y

def g(x):
    y = x**2 - 3
    z = 3*x -y
    y = z + x
    return z

# %%
def f(x):
    y = x**2-3
    return y

def g(x):
    y = x**2 - 3
    z = 3*x -y
    y = z + x
    return z

print("f(x) = ", f(int(input())))
print("f(x) = ", f(int(input())))
print("g(x) = ", g(int(input())))
print("g(x) = ", f(int(input())))
#f(2) = 1; f(0) = -3; g(1) = 5; g(3) = 3
# Out:
# 2
# f(x) =  1
# 0
# f(x) =  -3
# 1
# g(x) =  5
# 3
# g(x) =  6

# %% [markdown]
# # Exercice 2
#
# On considère les trois fonctions Python suivantes.
#
# Détaillez les calculs de $f1(5,1)$, $f2(5,1)$ et $f3(5,1)$. Vous listerez l’ensemble de toutes les affectations qui sont réalisées en indiquant si celles-ci ont lieu :
# * avant le début de la boucle ;
# * dans la boucle et, dans ce cas, au combientième tour de la boucle ;
# * après la sortie de la boucle.

# %%
def f1(x,y):
    z = 0
    while z<20:
        z = x+y
        x = 2*x
        y = 3*y
        z = y*z
    return z

def f2(x,y):
    z = 0
    while z < 20:
        z = x + y
        x = 2*x
        y = 3*y
    x = y*z
    return z

def f3(x,y):
    z = 0
    while z < 20:
        z = x + y
    x = 2*x
    y = 3*y
    return z

# %%
f1(5,1) :
    z = 0 #Avant la boucle
    #Tant que z < 20 : 
        #1er tour de la boucle
        z = 5 + 1 = 6
        x = 5 * 2 = 10
        y = 1 * 3 = 3
        z = 6 * 3 = 18
        #2e tour de la boucle
        z = 10 + 3
        x = 10 * 2 = 20
        y = 3 * 3 = 9
        z = 20 * 9 = 180

f2(5, 1) :
    z = 0 #Avant la boucle
    #Tant que z < 20 : 
        #1er tour de la boucle
        z = 5 + 1 = 6
        x = 5 * 2 = 10
        y = 1 * 3 = 3
        #2e tour de la boucle
        z = 10 * 3 = 30
        x = 10 * 2 = 20
        y = 3 * 3 = 9
    #Sortie de la boucle
    x = 9 * 30 = 270

f3(5, 1) : 
    z = 0 #Avant la boucle
    #Tant que z < 20 :
        #1er tour de la boucle
        z = 5 + 1
        #La condition de la boucle ne peut pas se compléter, donc c'est une boucle infinie.

# %% [markdown]
# # Exercice 3
#
# Le tableau suivant donne la mention en fonction de la note N obtenue à la première session du baccalauréat.
#
# |Condition | Mention|
# |---|---|
# |$0\leq N <8$ | Ajournée |
# |$8 \leq N <10$ | Rattrapage |
# |$10 \leq N < 12$ | Sans Mention |
# |$12 \leq N < 14$ | Assez Bien |
# |$14 \leq N < 16$ | Bien|
# |$N \geq 16$ |Très bien |
#
# Définissez une fonction Python qui prend une note en paramètre et renvoie la men-
# tion correspondante sous forme de chaîne de caractère.

# %%
def f(x):
    if x < 8:
        return "Ajournée"
    elif x < 10:
        return "Rattrapage"
    elif x < 12:
        return "Sans Mention"
    elif x < 14:
        return "Assez bien"
    elif x < 16:
        return "Bien"
    else:
        return "Très bien"
print(f(int(input())))
# Out:
# 14
# Bien

# %% [markdown]
# # Exercice 4
#
# 1. Recopiez et complétez le code suivant de la fonction <code> lancer </code> pour qu'elle simule le lancer d'un dé équilibré à six faces.
# ```
#         import random as rd
#
#         def lancer():
#             return rd.randint(...,...)
# ```
# 2. On souhaite réaliser une simulation du lancer de 1000 dés. Complétez le code
# suivant et exécutez le à la suite du code précédent afin de pouvoir remplir le
# tableau des effectifs correspondant à la série statistique de la simulation.

# %%
import random as rd

def lancer():
    return rd.randint(1, 6)
print(lancer())
# Out:
# 3

# %%
import random as rd

def lancer():
    return rd.randint(1, 6)
série = [0]*6
for i in range(1000):
    lancer()
    série[lancer()-1] += 1
print(série)
# Out:
# [174, 149, 190, 151, 160, 176]
